# %% [markdown]
# Consider the following Python dictionary `data` and Python list `labels`:
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# **1.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.

# %%
import pandas as pd
import numpy as np
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
df = pd.DataFrame(data,index =['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **2.** Display a summary of the basic information about this DataFrame and its data (*hint: there is a single method that can be called on the DataFrame*).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %% [markdown]
# **3.** Return the first 3 rows of the DataFrame `df`.

# %%
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# **4.** Display the 'animal' and 'age' columns from the DataFrame `df`

# %%
df.animal
# Out:
# a      cat
# b      cat
# c    snake
# d      dog
# e      dog
# f      cat
# g    snake
# h      cat
# i      dog
# j      dog
# Name: animal, dtype: object

# %%
df[["animal","age"]]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# **5.** Display the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']'

# %%
df.iloc[3:8,[0,1]]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN

# %% [markdown]
# **6.** Select only the rows where the number of visits is greater than 3.

# %%
df["visits"]>3
# Out:
# a    False
# b    False
# c    False
# d    False
# e    False
# f    False
# g    False
# h    False
# i    False
# j    False
# Name: visits, dtype: bool

# %% [markdown]
# **7.** Select the rows where the age is missing, i.e. it is `NaN`.

# %%
df[df["age"].isnull()]
# Out:
#   animal  age  visits priority  visit_one
# d    dog  NaN       3      yes          4
# h    cat  NaN       3      yes          4

# %% [markdown]
# **8.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
df[(df['animal']=='cat')&(df['age']<3)]
# Out:
#   animal  age  visits priority  visit_one
# a    cat  2.5       3      yes          4
# f    cat  2.0       3       no          4

# %% [markdown]
# ```
# `# This is formatted as code`
# ```
#
# **9.** Select the rows where the age is between 2 and 4 (inclusive)

# %%
df[df['age'].between(2,4)]

# %% [markdown]
# **10.** Change the age in row 'f' to 1.5.

# %%
df.at['f','age'] =1.5
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **11.** Calculate the sum of all visits in `df` (i.e. the total number of visits).

# %%
df['visits'].sum()
# Out:
# 19

# %% [markdown]
# **12.** Calculate the mean age for each different animal in `df`.

# %%
df.groupby(by='animal')['age'].mean()
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %% [markdown]
# **13.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
data1=df.append({'animal':'cat', 'age':2.3, 'visits':2,'priority': 'yes'},ignore_index=True)
data1
# Out:
# <ipython-input-32-e880c13a880c>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data1=df.append({'animal':'cat', 'age':2.3, 'visits':2,'priority': 'yes'},ignore_index=True)
#    animal  age  visits priority
# 0     cat  2.5       1      yes
# 1     cat  3.0       3      yes
# 2   snake  0.5       2       no
# 3     dog  NaN       3      yes
# 4     dog  5.0       2       no
# 5     cat  2.0       3       no
# 6   snake  4.5       1       no
# 7     cat  NaN       1      yes
# 8     dog  7.0       2       no
# 9     dog  3.0       1       no
# 10    cat  2.3       2      yes

# %% [markdown]
# **14.** Count the number of each type of animal in `df`.

# %%
df.groupby(by='animal')['age'].count()
# Out:
# animal
# cat      3
# dog      3
# snake    2
# Name: age, dtype: int64

# %% [markdown]
# **15.** Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).

# %%
df.head()
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no

# %%
df.sort_values(by=['age','visits'],ascending =[False,True])
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  2.0       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %% [markdown]
# **16.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.

# %%
df['priority']=df['priority'].map({'yes':True,'no':False})
df
# Out:
#   animal  age  visits  priority
# a    cat  2.5       1      True
# b    cat  3.0       3      True
# c  snake  0.5       2     False
# d    dog  NaN       3      True
# e    dog  5.0       2     False
# f    cat  2.0       3     False
# g  snake  4.5       1     False
# h    cat  NaN       1      True
# i    dog  7.0       2     False
# j    dog  3.0       1     False

# %% [markdown]
# **17.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
df['animal'] = df['animal'].replace('snake','python')
df
# Out:
#    animal  age  visits  priority
# a     cat  2.5       1      True
# b     cat  3.0       3      True
# c  python  0.5       2     False
# d     dog  NaN       3      True
# e     dog  5.0       2     False
# f     cat  2.0       3     False
# g  python  4.5       1     False
# h     cat  NaN       1      True
# i     dog  7.0       2     False
# j     dog  3.0       1     False

# %% [markdown]
# **18.** Load the ny-flights dataset to Python

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data =pd.read_csv('/content/ny-flights.csv')
data
# Out:
#                    fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0      2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1      2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2      2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3      2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4      2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
# ...                    ...            ...         ...      ...     ...    ...
# 20812  2014-01-31 00:00:00             UA       19977   N54711    1253    ROC
# 20813  2014-01-31 00:00:00             UA       19977   N77525    1429    LGA
# 20814  2014-01-31 00:00:00             UA       19977   N37293    1456    LGA
# 20815  2014-01-31 00:00:00             UA       19977   N24729    1457    LGA
# 20816  2014-01-31 00:00:00             MQ       20398   N609MQ    3699    BUF
#
# ...

# %% [markdown]
# **19.** Which airline ID is present maximum times in the dataset

# %%
most_value= data['airline_id'].value_counts().idxmax()
most_value
# Out:
# 20409

# %% [markdown]
# **20.** Draw a plot between dep_delay and arr_delay

# %%
data['origin'].nunique()
# Out:
# 11

# %%
data['unique_carrier'].nunique()
# Out:
# 13

# %%
data.groupby("origin")[['dep_delay','arr_delay']].sum().plot(kind='barh')
plt.show()

# %%
plt.title('categoris')
sns.countplot(x='origin',data=data)
# Out:
# <Axes: title={'center': 'categoris'}, xlabel='origin', ylabel='count'>

# %%
plt.figure(figsize=(7,7))
sns.barplot(x='origin',y='dep_delay',data=data)
# Out:
# <Axes: xlabel='origin', ylabel='dep_delay'>

# %%
plt.figure(figsize=(7,7))
sns.barplot(x='origin',y='arr_delay',data=data)
# Out:
# <Axes: xlabel='origin', ylabel='arr_delay'>
